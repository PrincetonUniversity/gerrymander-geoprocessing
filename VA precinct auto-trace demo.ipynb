# %%
import sys
sys.path.append('/Users/wtadler/Repos/gerrymander-geoprocessing')
from IPython import display
from workflow import flood_fill, find_blocks, make_map

# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/wtadler/miniconda3/envs/demo/lib/python3.7/site-packages/pysal/__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysal` 2.0 prelease candidate. The API changes and a guide on how to change imports is provided at https://migrating.pysal.org
#   ), VisibleDeprecationWarning)
# /Users/wtadler/miniconda3/envs/demo/lib/python3.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
img_in = 'AlexandriaCity/AlexandriaCity.png'
display.Image(img_in, width=800)

# %%
filled = flood_fill(img_in  = img_in,
                    img_out = 'AlexandriaCity/AlexandriaCity_floodfilled.png')
# Out:
# Color 0:
# <PIL.Image.Image image mode=RGB size=44x44 at 0x1A24B29DD8>
# Color 1:
# <PIL.Image.Image image mode=RGB size=44x44 at 0x1A24B29E10>
# Color 2:
# <PIL.Image.Image image mode=RGB size=44x44 at 0x1A24B29E10>
# Color 3:
# <PIL.Image.Image image mode=RGB size=44x44 at 0x1A24B29E10>
# Which color are the precinct boundaries?
# 1
#
# Okay! Finding precinct boundaries...
# ...
# Flood filling with random colors...
# ...
# <PIL.Image.Image image mode=RGB size=1432x886 at 0x1A24B29C50>

# %%
blocks, precincts = find_blocks(filled,
                                blocks_path = 'AlexandriaCity/census_blocks.shp',
                                out_path = 'AlexandriaCity/precincts.shp')
# Out:
# Assigning each block...
# ...

# %%
make_map(blocks, precincts)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
